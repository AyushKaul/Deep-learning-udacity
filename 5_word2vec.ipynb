# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3081, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.113319
# Nearest to as: telekom, dominos, channeled, saucer, reflux, integrals, bacharach, manchukuo,
# Nearest to used: harbor, hymenoptera, dct, anthems, headmaster, tarmac, commemorate, emporia,
# Nearest to world: mikoto, fanbase, mil, sapir, waters, museo, nebula, chaparral,
# Nearest to only: bsd, rod, lung, true, offenbach, scullin, oncoming, isotope,
# Nearest to th: noise, prostate, rampage, fogo, barbarossa, codon, hymn, headland,
# Nearest to has: evo, naur, loved, bai, david, machete, invests, son,
# Nearest to or: upgrading, degradation, converters, homomorphisms, ingram, emulsions, misskelley, gorilla,
# Nearest to not: rigs, cannibalistic, smack, quanta, thee, fluorine, capitalistic, surnames,
# Nearest to eight: wrc, exercised, breath, cigars, codebreakers, elric, normalized, adverbs,
# Nearest to five: baasha, bloomberg, sour, disperse, performance, yitzchak, proliferated, drilling,
# Nearest to may: customary, raven, saviola, turnpike, pubescent, reliever, coats, beer,
# Nearest to b: mankiewicz, annals, jamal, aleksandar, honoria, franjo, bottlenecks, nagoya,
# Nearest to of: emo, numeration, detached, styled, step, pretender, safi, lengthen,
# Nearest to state: accreditation, otherwise, insulate, ey, hydrophobic, anatta, technische, levite,
# Nearest to can: rationality, establishes, dashed, service, gz, frederick, lazar, hustler,
# Nearest to on: splashdown, triumphed, semiconducting, dutch, enterprise, evangelicals, glorioso, differential,
# Average loss at step 2000: 4.375430
# Average loss at step 4000: 3.869737
# Average loss at step 6000: 3.792042
# Average loss at step 8000: 3.683360
# Average loss at step 10000: 3.614584
# Nearest to as: recessions, ncipe, whitespace, sheol, dogg, dominos, cheques, telekom,
# Nearest to used: written, hymenoptera, forms, formaldehyde, anthems, niccolo, known, emporia,
# Nearest to world: sapir, hynek, laud, thru, mil, mikoto, specific, stereotypes,
# Nearest to only: bsd, oncoming, true, nephews, appraisal, seconded, man, lung,
# Nearest to th: noise, four, prostate, three, rampage, eight, ecclesiasticus, reconquest,
# Nearest to has: had, was, have, loved, is, balanchine, while, loving,
# Nearest to or: and, than, flatland, advisors, s, nameserver, advised, impiety,
# Nearest to not: who, they, it, to, often, brisance, rawls, you,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to five: six, seven, eight, three, nine, four, zero, two,
# Nearest to may: can, would, customary, will, could, mantra, turnpike, raven,
# Nearest to b: annals, mankiewicz, jamal, brummell, gallo, honoria, aleksandar, bunk,
# Nearest to of: in, and, collapse, diode, karelia, elia, bar, belted,
# Nearest to state: technische, rove, levite, reforming, cavalcanti, accreditation, hynek, amplifies,
# Nearest to can: may, should, could, rationality, would, mo, nepos, counterpoint,
# Nearest to on: in, at, sperm, jacks, into, through, backyard, last,
# Average loss at step 12000: 3.608747
# Average loss at step 14000: 3.576775
# Average loss at step 16000: 3.411883
# Average loss at step 18000: 3.456267
# Average loss at step 20000: 3.544425
# Nearest to as: sheol, deduce, channeled, ncipe, croatia, cura, spraying, recessions,
# Nearest to used: written, known, found, anthems, preservatives, hymenoptera, shocks, held,
# Nearest to world: laud, sapir, republic, neberg, hynek, financially, taping, mikoto,
# Nearest to only: oncoming, true, not, bsd, annul, bunkers, tradeoffs, selma,
# Nearest to th: noise, prostate, four, three, ecclesiasticus, rfc, spying, reconquest,
# Nearest to has: had, was, is, have, loved, balanchine, while, became,
# Nearest to or: and, than, carracci, flatland, fg, outcrops, seth, might,
# Nearest to not: usually, they, it, generally, also, still, to, always,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to five: six, four, three, seven, eight, two, zero, nine,
# Nearest to may: can, would, could, should, will, might, must, mantra,
# Nearest to b: d, bunk, bipolar, gallo, shirt, pigment, brummell, hosea,
# Nearest to of: same, for, tokens, collapse, shiva, piqad, gon, overwrite,
# Nearest to state: rove, surname, whole, cavalcanti, city, reforming, impotence, amplifies,
# Nearest to can: may, could, should, would, will, might, cannot, copying,
# Nearest to on: in, at, upon, jacks, into, opposite, mohawk, sperm,
# Average loss at step 22000: 3.507207
# Average loss at step 24000: 3.491483
# Average loss at step 26000: 3.482351
# Average loss at step 28000: 3.482183
# Average loss at step 30000: 3.505412
# Nearest to as: recessions, vassalage, cura, sheol, lehi, spraying, swedes, became,
# Nearest to used: known, written, found, held, referred, described, preservatives, available,
# Nearest to world: laud, taping, republic, sapir, hynek, stram, immediately, abraham,
# Nearest to only: oncoming, not, annul, esr, journ, actually, true, adornment,
# Nearest to th: six, eight, noise, nd, rfc, prostate, ce, reconquest,
# Nearest to has: had, is, have, was, having, loved, mabuse, while,
# Nearest to or: and, than, presheaf, pandemonium, sikkim, nameserver, caverns, minucius,
# Nearest to not: they, still, you, usually, often, always, there, generally,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to five: four, eight, seven, six, three, nine, zero, two,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to b: d, bunk, hosea, rubbish, resolves, shirt, standby, gallo,
# Nearest to of: in, highest, surrounding, israeli, and, during, principalities, from,
# Nearest to state: rove, lanthanides, whole, surname, salam, technische, city, selangor,
# Nearest to can: may, could, would, will, should, must, cannot, might,
# Nearest to on: upon, in, through, sperm, from, jacks, at, incendiary,
# Average loss at step 32000: 3.502289
# Average loss at step 34000: 3.500168
# Average loss at step 36000: 3.455383
# Average loss at step 38000: 3.297957
# Average loss at step 40000: 3.427213
# Nearest to as: cura, recessions, when, mathworld, gadgets, metropolises, be, lili,
# Nearest to used: known, found, referred, written, available, held, described, designed,
# Nearest to world: appendices, u, republic, stimson, immediately, bombard, laud, descriptor,
# Nearest to only: just, journ, even, you, jewry, still, warhol, noor,
# Nearest to th: six, eight, ad, ce, nd, seven, noise, three,
# Nearest to has: had, have, was, is, having, newbies, loved, gerry,
# Nearest to or: and, than, caver, swirling, inelastic, arran, inbound, nameserver,
# Nearest to not: usually, still, always, they, often, it, generally, also,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to five: six, seven, four, three, eight, two, nine, zero,
# Nearest to may: can, could, would, will, should, might, must, cannot,
# Nearest to b: d, r, f, h, nicol, c, UNK, hosea,
# Nearest to of: in, from, bv, for, crisp, legislate, numeration, queenie,
# Nearest to state: city, salam, surname, hangovers, rove, amplifies, selangor, cherokee,
# Nearest to can: may, could, will, would, should, must, might, cannot,
# Nearest to on: upon, at, in, during, earp, against, between, within,
# Average loss at step 42000: 3.434184
# Average loss at step 44000: 3.456240
# Average loss at step 46000: 3.454232
# Average loss at step 48000: 3.361255
# Average loss at step 50000: 3.386116
# Nearest to as: nagel, recessions, became, haemophilia, swedes, deduce, magical, cura,
# Nearest to used: known, referred, written, found, given, designed, available, described,
# Nearest to world: appendices, republic, bombard, affirmative, stimson, season, immediately, descriptor,
# Nearest to only: still, characterizing, sahelian, adornment, not, you, journ, appraisal,
# Nearest to th: ad, ce, four, one, six, noise, three, nd,
# Nearest to has: had, have, was, is, newbies, having, does, hornet,
# Nearest to or: and, than, potos, languedoc, outcrops, axiomatization, adrift, presheaf,
# Nearest to not: still, generally, usually, concocted, they, who, you, always,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to b: d, f, resolves, x, h, vindhya, c, p,
# Nearest to of: in, and, lyra, surrounding, undiscovered, manatee, same, including,
# Nearest to state: salam, city, conservatoire, complaints, selangor, anatta, messianic, ces,
# Nearest to can: could, may, would, will, should, must, might, cannot,
# Nearest to on: upon, in, through, within, across, at, backhand, incur,
# Average loss at step 52000: 3.438526
# Average loss at step 54000: 3.430136
# Average loss at step 56000: 3.438349
# Average loss at step 58000: 3.398938
# Average loss at step 60000: 3.396171
# Nearest to as: recessions, when, shaivism, lear, metallic, fiendish, xers, unseen,
# Nearest to used: known, written, seen, referred, available, designed, described, found,
# Nearest to world: appendices, u, stimson, bothnian, laud, jug, cold, sculpture,
# Nearest to only: usually, also, journ, not, always, unobstructed, sheol, adornment,
# Nearest to th: ad, six, five, ce, nd, bc, eight, four,
# Nearest to has: had, have, was, is, having, newbies, although, ayub,
# Nearest to or: and, than, but, pepper, languedoc, revitalized, like, demeter,
# Nearest to not: usually, still, you, they, always, this, it, to,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to five: six, four, three, eight, seven, nine, zero, two,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to b: d, f, p, vindhya, k, c, x, m,
# Nearest to of: mugabe, for, in, including, same, lyra, include, like,
# Nearest to state: city, conservatoire, anatta, annuals, lilian, messianic, town, salam,
# Nearest to can: could, may, would, will, should, must, might, cannot,
# Nearest to on: upon, through, in, jacks, within, across, at, mansur,
# Average loss at step 62000: 3.239526
# Average loss at step 64000: 3.254498
# Average loss at step 66000: 3.408027
# Average loss at step 68000: 3.392689
# Average loss at step 70000: 3.363669
# Nearest to as: xers, cura, shaivism, enormous, channeled, szil, when, recessions,
# Nearest to used: known, written, seen, designed, described, available, referred, found,
# Nearest to world: u, barents, season, bothnian, appendices, cold, unmistakable, stimson,
# Nearest to only: journ, always, not, incisors, homogenous, recursion, actually, survived,
# Nearest to th: ad, bc, ce, six, four, eight, nd, curricula,
# Nearest to has: had, have, was, is, although, newbies, ayub, laser,
# Nearest to or: and, than, any, while, thrill, amended, luminiferous, dragonfly,
# Nearest to not: usually, never, still, now, always, subversive, generally, you,
# Nearest to eight: nine, six, seven, five, four, three, zero, one,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to b: f, d, r, x, p, h, vindhya, k,
# Nearest to of: including, include, crystallization, incumbent, in, initial, lyra, for,
# Nearest to state: conservatoire, ces, city, annuals, gabor, lilian, states, hangovers,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to on: upon, through, within, in, jacks, incur, across, richest,
# Average loss at step 72000: 3.377997
# Average loss at step 74000: 3.350074
# Average loss at step 76000: 3.319105
# Average loss at step 78000: 3.350560
# Average loss at step 80000: 3.377945
# Nearest to as: deduce, when, xers, gabriele, particularly, cura, ncipe, factually,
# Nearest to used: known, written, referred, seen, available, described, designed, found,
# Nearest to world: u, unmistakable, winds, barents, cold, appendices, laud, arrivals,
# Nearest to only: journ, actually, always, usually, homogenous, stench, still, normally,
# Nearest to th: bc, ad, ce, nd, five, eight, six, four,
# Nearest to has: had, have, is, was, although, ayub, does, provides,
# Nearest to or: and, than, versus, while, but, jpg, revitalized, fredericksburg,
# Nearest to not: still, usually, always, you, never, it, generally, they,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to may: can, could, would, will, might, should, must, cannot,
# Nearest to b: d, c, f, r, vindhya, demille, k, p,
# Nearest to of: including, incumbent, in, eldest, concerning, from, electrostatics, qur,
# Nearest to state: city, cherokee, ces, annuals, anatta, vertebrate, government, lilian,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to on: upon, through, in, within, at, under, jacks, during,
# Average loss at step 82000: 3.409058
# Average loss at step 84000: 3.408660
# Average loss at step 86000: 3.389024
# Average loss at step 88000: 3.354156
# Average loss at step 90000: 3.364092
# Nearest to as: deduce, xers, bv, including, withdrawing, shaivism, ursidae, recessions,
# Nearest to used: known, referred, seen, written, described, available, called, designed,
# Nearest to world: barents, winds, u, unmistakable, jug, arrivals, cold, bootlegged,
# Nearest to only: even, actually, tourists, journ, sheol, fixation, dosing, stench,
# Nearest to th: ad, ce, nine, bc, six, five, nd, seven,
# Nearest to has: had, have, is, was, having, ayub, although, provides,
# Nearest to or: and, than, while, including, but, versus, revitalized, sowell,
# Nearest to not: still, surnames, usually, never, also, generally, only, there,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to five: eight, seven, four, six, three, nine, zero, two,
# Nearest to may: can, could, might, would, will, must, should, cannot,
# Nearest to b: d, c, r, f, k, demille, docks, resolves,
# Nearest to of: incumbent, for, including, in, electrostatics, epicurus, diode, and,
# Nearest to state: city, ces, tenacity, anatta, cherokee, town, electrotechnical, uighur,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to on: upon, through, at, within, under, conquers, mustafa, jacks,
# Average loss at step 92000: 3.394852
# Average loss at step 94000: 3.258891
# Average loss at step 96000: 3.359420
# Average loss at step 98000: 3.242308
# Average loss at step 100000: 3.355718
# Nearest to as: deduce, bv, recessions, cura, when, gabriele, like, ursidae,
# Nearest to used: known, designed, referred, written, available, seen, considered, described,
# Nearest to world: u, season, unmistakable, barents, yana, arrivals, pashto, bootlegged,
# Nearest to only: even, actually, you, journ, fixation, binet, still, tourists,
# Nearest to th: ce, ad, nd, bc, fifth, fourth, third, gdynia,
# Nearest to has: had, have, is, was, since, having, provides, ayub,
# Nearest to or: and, than, versus, pepper, revitalized, luminiferous, while, inelastic,
# Nearest to not: never, still, always, surnames, t, only, chromite, also,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to may: can, could, might, would, should, will, must, cannot,
# Nearest to b: d, nicol, c, pup, resolves, baccalaureate, r, ghulam,
# Nearest to of: including, bv, in, eldest, and, rimet, electrostatics, qur,
# Nearest to state: city, ces, anatta, mesh, uighur, provincial, annuals, cherokee,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to on: upon, within, through, in, jacks, at, under, contiguous,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
    assert skip_window%2==1
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    # num_skips => # of times we select a random word within the span?
    # batch_size (8) and num_skips (2) (4 times)
    # batch_size (8) and num_skips (1) (8 times)
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself
 
        # do this num_skips (2 times)
        # do this (1 time)
 
        # add selected target to avoid_list for next time
        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

# %%
if __name__ == '__main__':
    batch_size = 128
    embedding_size = 128 # Dimension of the embedding vector.
    skip_window = 1 # How many words to consider left and right.
    num_skips = 2 # How many times to reuse an input to generate a label.
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100 # Only pick dev samples in the head of the distribution.
    # pick 16 samples from 100
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples,random.sample(range(1000,1000+valid_window), valid_size//2))
    num_sampled = 64 # Number of negative examples to sample.
 
    graph = tf.Graph()
 
    with graph.as_default(), tf.device('/cpu:0'):
 
        # Input data.
        train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
        train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
 
        # Variables.
        # embedding, vector for each word in the vocabulary
        embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
        softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
        # Model.
        embeds = None
        for i in range(2*skip_window):
            embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
            print('embedding %d shape: %s'%(i,embedding_i.get_shape().as_list()))
            emb_x,emb_y = embedding_i.get_shape().as_list()
            if embeds is None:
                embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
            else:
                embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])],2)
                
        assert embeds.get_shape().as_list()[2]==2*skip_window
        print("Concat embedding size: %s"%embeds.get_shape().as_list())
        avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
        print("Avg embedding size: %s"%avg_embed.get_shape().as_list())

#         print(avg_embed.dtype)
#         print(softmax_weights.dtype)
#         loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, avg_embed,
#                        train_labels, num_sampled, vocabulary_size))
        loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

        optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
 
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
        similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps=100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.561981
# Nearest to while: implosion, sexually, adhere, rebelling, carnival, crowded, ejaculate, bards,
# Nearest to one: twinning, itinerary, rifles, hyperinsulinism, kyle, lesser, soot, tactician,
# Nearest to but: tact, buzz, conforms, netherland, stephane, lighten, solidifies, candela,
# Nearest to will: receipts, respiratory, flocks, constantly, rationalization, freenode, authentic, hemiparesis,
# Nearest to many: marshallese, anus, tommy, oligarchic, indispensable, senussi, sash, irresistible,
# Nearest to and: routes, devo, northwest, chen, barents, qcd, solanaceae, yonkers,
# Nearest to use: radically, briefcase, sixths, refuge, amber, biplane, pinyin, marmalade,
# Nearest to on: wuppertal, seaton, resented, rest, pungent, ktav, fend, eastwood,
# Nearest to operating: bmx, sistine, small, buckwheat, exploring, sutras, duodenum, nave,
# Nearest to account: chateau, gath, sulfuric, cuny, happiness, guerre, gallen, karol,
# Nearest to active: lovelock, journeyman, circumcisions, posse, benedictines, lorica, exploding, beck,
# Nearest to assembly: joram, heathland, intimidated, planted, ceded, refuge, bleaching, real,
# Nearest to road: ewen, molinari, zangger, tylor, doc, quadrant, continuous, eui,
# Nearest to existence: synthesized, indignant, hyperthyroidism, preprocessing, give, anfield, middlesex, decoration,
# Nearest to police: mnemonics, francois, transoxiana, mussorgsky, faust, amyl, mitzvot, lethargy,
# Nearest to pressure: suspicions, lin, ram, utopian, cleared, hawthorne, algeria, perkin,
# Average loss at step 2000: 4.037950
# Average loss at step 4000: 3.501529
# Average loss at step 6000: 3.341271
# Average loss at step 8000: 3.187982
# Average loss at step 10000: 3.150491
# Nearest to while: with, mosiah, adhere, andaman, embarked, carnival, crowded, implosion,
# Nearest to one: madhu, two, cryopreservation, scurvy, cadet, eight, martinez, facet,
# Nearest to but: buzz, if, unschooling, does, mbe, ditches, strongly, attlee,
# Nearest to will: can, could, may, would, must, might, adorned, rewrote,
# Nearest to many: senussi, various, all, contamination, some, toriyama, several, nur,
# Nearest to and: or, devo, bolivia, feudal, interplay, ultimate, miscible, kets,
# Nearest to use: cypriots, content, sixths, bodies, amber, radically, scope, loma,
# Nearest to on: in, ktav, through, with, hearth, selfless, at, circumpolar,
# Nearest to operating: small, nave, bmx, sutras, sistine, duodenum, wallet, adjunct,
# Nearest to account: happiness, gath, sandstone, hideous, stat, cuny, chateau, karol,
# Nearest to active: posse, lovelock, operates, benedictines, lorica, transboundary, mentions, caver,
# Nearest to assembly: joram, intimidated, heathland, planted, refuge, real, archetype, bleaching,
# Nearest to road: ewen, tylor, molinari, zangger, speaking, doc, continuous, eui,
# Nearest to existence: indignant, middlesex, hyperthyroidism, finegold, synthesized, anfield, coins, preprocessing,
# Nearest to police: mnemonics, francois, mussorgsky, transoxiana, faust, underground, philosophers, amyl,
# Nearest to pressure: suspicions, ram, lin, clams, cleared, algeria, utopian, weep,
# Average loss at step 12000: 3.175987
# Average loss at step 14000: 3.126579
# Average loss at step 16000: 3.148059
# Average loss at step 18000: 3.103669
# Average loss at step 20000: 2.998992
# Nearest to while: mosiah, ejaculate, embarked, with, although, implosion, carnival, ncaa,
# Nearest to one: two, eight, cryopreservation, scurvy, seven, particular, cadet, three,
# Nearest to but: however, and, unschooling, does, strongly, const, buzz, pinkish,
# Nearest to will: can, could, may, would, must, might, should, to,
# Nearest to many: some, several, various, senussi, these, all, contamination, those,
# Nearest to and: or, miscible, but, tinker, vampyre, which, graphing, steffi,
# Nearest to use: content, neoclassicism, scope, example, amber, hydrophilic, bodies, cypriots,
# Nearest to on: through, upon, in, ktav, letting, at, presocratic, between,
# Nearest to operating: small, sistine, nave, defendants, bmx, wallet, exploring, slowest,
# Nearest to account: happiness, gath, stat, hideous, somaliland, sandstone, ordering, karol,
# Nearest to active: posse, operates, lovelock, benedictines, kuril, journeyman, berliners, guildford,
# Nearest to assembly: joram, intimidated, heathland, real, planted, lowers, refuge, archetype,
# Nearest to road: doc, tylor, zangger, speaking, rhus, cup, continuous, molinari,
# Nearest to existence: indignant, middlesex, finegold, anfield, lambar, coins, buckle, hyperthyroidism,
# Nearest to police: mnemonics, underground, mussorgsky, philosophers, francois, faust, systems, transoxiana,
# Nearest to pressure: clams, ram, algeria, weep, suspicions, utopian, cleared, lin,
# Average loss at step 22000: 3.055094
# Average loss at step 24000: 3.029929
# Average loss at step 26000: 2.992155
# Average loss at step 28000: 3.012881
# Average loss at step 30000: 2.990747
# Nearest to while: ejaculate, mosiah, although, with, embarked, flapping, partake, shared,
# Nearest to one: two, five, six, four, three, madhu, scurvy, seven,
# Nearest to but: however, and, see, aquifer, pinkish, hoffa, dmu, erdrich,
# Nearest to will: can, could, would, may, must, might, should, cannot,
# Nearest to many: some, several, various, these, numerous, senussi, most, those,
# Nearest to and: or, but, tinker, minogue, vampyre, serious, escorting, monet,
# Nearest to use: neoclassicism, example, beings, hydrophilic, presenters, content, scope, rift,
# Nearest to on: upon, through, in, letting, at, around, evangelium, incline,
# Nearest to operating: small, sistine, nave, defendants, crossed, wallet, falsified, sutras,
# Nearest to account: happiness, gath, hideous, stat, somaliland, nephritis, ordering, duran,
# Nearest to active: operates, posse, lovelock, kuril, journeyman, headlined, benedictines, mears,
# Nearest to assembly: joram, intimidated, heathland, planted, lowers, serif, real, zoological,
# Nearest to road: rhus, doc, cup, continuous, eui, speaking, ewen, quadrant,
# Nearest to existence: indignant, middlesex, finegold, anfield, lambar, coins, slayton, targaryen,
# Nearest to police: underground, mnemonics, systems, mussorgsky, philosophers, faust, davenport, francois,
# Nearest to pressure: clams, weep, ram, cleared, algeria, primed, suspicions, cnidaria,
# Average loss at step 32000: 2.841668
# Average loss at step 34000: 2.950408
# Average loss at step 36000: 2.935692
# Average loss at step 38000: 2.936347
# Average loss at step 40000: 2.920528
# Nearest to while: although, ejaculate, and, with, when, mosiah, or, flapping,
# Nearest to one: two, six, dsm, madhu, seven, three, particular, facet,
# Nearest to but: however, and, translational, kahanamoku, stored, sickle, dmu, unschooling,
# Nearest to will: can, could, would, may, must, might, should, cannot,
# Nearest to many: some, several, various, numerous, most, those, these, senussi,
# Nearest to and: or, but, minogue, fiefdom, while, vampyre, isopropanol, uncountably,
# Nearest to use: content, neoclassicism, carry, presenters, beings, hydrophilic, scope, appearance,
# Nearest to on: upon, through, seekers, within, incline, valera, in, evangelium,
# Nearest to operating: defendants, sistine, small, nave, crossed, numeral, falsified, wallet,
# Nearest to account: happiness, gath, hideous, somaliland, stat, nephritis, sexist, chateau,
# Nearest to active: operates, posse, kuril, headlined, lovelock, journeyman, ware, mears,
# Nearest to assembly: joram, intimidated, serif, lowers, zoological, planted, archetype, heathland,
# Nearest to road: doc, cup, rhus, continuous, ewen, guyanese, speaking, eui,
# Nearest to existence: indignant, middlesex, anfield, finegold, lambar, slayton, targaryen, zyklon,
# Nearest to police: underground, systems, mnemonics, davenport, mussorgsky, philosophers, sequences, francois,
# Nearest to pressure: clams, weep, rockford, algeria, ram, primed, conflicts, cleared,
# Average loss at step 42000: 2.943655
# Average loss at step 44000: 2.945357
# Average loss at step 46000: 2.903728
# Average loss at step 48000: 2.872660
# Average loss at step 50000: 2.848213
# Nearest to while: although, when, ejaculate, but, were, overbeck, and, including,
# Nearest to one: four, two, facet, madhu, saeima, seven, scurvy, psychiatrists,
# Nearest to but: however, and, although, kahanamoku, while, unschooling, see, sickle,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to many: some, several, various, numerous, these, most, all, those,
# Nearest to and: or, but, isopropanol, ultimate, including, while, than, vampyre,
# Nearest to use: neoclassicism, content, carry, hydrophilic, beings, history, scope, presenters,
# Nearest to on: upon, through, in, within, under, seaton, at, seekers,
# Nearest to operating: numeral, defendants, nervous, sistine, nave, crossed, seq, falsified,
# Nearest to account: happiness, sexist, gath, hideous, somaliland, ordering, nephritis, luo,
# Nearest to active: operates, posse, kuril, ware, mears, headlined, journeyman, lovelock,
# Nearest to assembly: joram, intimidated, serif, lowers, zoological, archetype, ramayana, skin,
# Nearest to road: cup, doc, rhus, ewen, continuous, oriente, gallbladder, speaking,
# Nearest to existence: indignant, finegold, middlesex, anfield, lambar, slayton, targaryen, polg,
# Nearest to police: underground, systems, mussorgsky, mnemonics, davenport, philosophers, sequences, michigan,
# Nearest to pressure: weep, clams, rockford, conflicts, cheques, primed, cubans, ram,
# Average loss at step 52000: 2.884317
# Average loss at step 54000: 2.865080
# Average loss at step 56000: 2.860960
# Average loss at step 58000: 2.762618
# Average loss at step 60000: 2.826426
# Nearest to while: although, when, including, and, ejaculate, overbeck, with, but,
# Nearest to one: two, four, six, nine, five, seven, dsm, three,
# Nearest to but: however, although, and, see, though, while, dmu, which,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to many: some, several, various, numerous, those, all, these, most,
# Nearest to and: but, or, while, isopropanol, however, although, minogue, skis,
# Nearest to use: neoclassicism, content, carry, presenters, hydrophilic, sense, insurgents, list,
# Nearest to on: upon, through, in, within, at, around, under, valera,
# Nearest to operating: defendants, numeral, nervous, nave, sistine, crossed, slowest, rotation,
# Nearest to account: happiness, sexist, hideous, gath, ordering, nephritis, somaliland, luo,
# Nearest to active: operates, posse, ware, kuril, headlined, journeyman, leveraged, mears,
# Nearest to assembly: joram, intimidated, serif, lowers, zoological, ramayana, craven, archetype,
# Nearest to road: rhus, cup, continuous, doc, ewen, elegance, gallbladder, guyanese,
# Nearest to existence: indignant, finegold, anfield, targaryen, middlesex, lambar, slayton, depletion,
# Nearest to police: underground, davenport, systems, mussorgsky, philosophers, sequences, mnemonics, decatur,
# Nearest to pressure: weep, clams, rockford, cubans, conflicts, cheques, schools, primed,
# Average loss at step 62000: 2.830851
# Average loss at step 64000: 2.775545
# Average loss at step 66000: 2.771619
# Average loss at step 68000: 2.720157
# Average loss at step 70000: 2.773355
# Nearest to while: although, when, including, ejaculate, with, and, though, however,
# Nearest to one: two, madhu, five, seven, six, three, dsm, saeima,
# Nearest to but: however, although, and, though, despite, see, dmu, which,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to many: some, several, various, numerous, those, these, all, most,
# Nearest to and: or, but, vampyre, isopropanol, miscible, ultimate, while, including,
# Nearest to use: neoclassicism, content, sense, presenters, scope, carry, radiotelephone, aerials,
# Nearest to on: upon, in, through, around, at, under, within, kristofferson,
# Nearest to operating: defendants, numeral, nervous, file, storage, sistine, nave, solar,
# Nearest to account: sexist, happiness, gath, ordering, nephritis, hideous, somaliland, luo,
# Nearest to active: operates, posse, important, ware, contained, utah, schwarzschild, kuril,
# Nearest to assembly: joram, intimidated, serif, lowers, zoological, incredible, ramayana, skin,
# Nearest to road: rhus, cup, guyanese, continuous, ewen, doc, gallbladder, elegance,
# Nearest to existence: indignant, finegold, lambar, targaryen, anfield, depletion, slayton, middlesex,
# Nearest to police: underground, systems, davenport, military, mussorgsky, philosophers, sequences, labor,
# Nearest to pressure: clams, weep, rockford, cubans, conflicts, cheques, christine, ram,
# Average loss at step 72000: 2.800091
# Average loss at step 74000: 2.656292
# Average loss at step 76000: 2.803128
# Average loss at step 78000: 2.826051
# Average loss at step 80000: 2.782662
# Nearest to while: although, when, though, ejaculate, for, lev, overbeck, flapping,
# Nearest to one: two, madhu, dsm, seven, six, five, sag, four,
# Nearest to but: however, although, and, though, see, which, dmu, despite,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to many: some, several, various, numerous, those, all, most, these,
# Nearest to and: or, but, including, minogue, isopropanol, although, tinker, nol,
# Nearest to use: neoclassicism, sense, content, scope, list, radiotelephone, living, secretion,
# Nearest to on: upon, through, in, around, under, during, incline, within,
# Nearest to operating: numeral, defendants, nervous, storage, solar, sistine, seq, slowest,
# Nearest to account: sexist, happiness, gath, nephritis, luo, somaliland, ordering, thinking,
# Nearest to active: operates, important, posse, schwarzschild, utah, contained, earlier, leveraged,
# Nearest to assembly: joram, intimidated, serif, lowers, zoological, ramayana, incredible, skin,
# Nearest to road: rhus, cup, guyanese, continuous, gallbladder, quadrant, elegance, ewen,
# Nearest to existence: indignant, finegold, lambar, depletion, middlesex, polg, targaryen, presence,
# Nearest to police: underground, military, systems, davenport, labor, mussorgsky, philosophers, secretary,
# Nearest to pressure: clams, weep, rockford, cubans, norepinephrine, cheques, conflicts, schools,
# Average loss at step 82000: 2.679119
# Average loss at step 84000: 2.771252
# Average loss at step 86000: 2.743737
# Average loss at step 88000: 2.759417
# Average loss at step 90000: 2.741358
# Nearest to while: although, when, though, however, or, before, flapping, including,
# Nearest to one: two, six, four, eight, madhu, sag, seven, nine,
# Nearest to but: however, although, though, see, which, and, despite, bipm,
# Nearest to will: would, can, could, should, may, must, might, cannot,
# Nearest to many: some, several, numerous, various, most, all, those, these,
# Nearest to and: or, minogue, but, including, isopropanol, hgp, although, tinker,
# Nearest to use: neoclassicism, sense, content, carry, radiotelephone, throw, living, meaning,
# Nearest to on: upon, in, through, around, within, evangelium, under, incline,
# Nearest to operating: numeral, nervous, defendants, storage, file, solar, nave, sistine,
# Nearest to account: sexist, happiness, nephritis, somaliland, gath, luo, thinking, ordering,
# Nearest to active: operates, important, posse, contained, utah, leveraged, earlier, ural,
# Nearest to assembly: joram, serif, intimidated, lowers, zoological, ramayana, congress, incredible,
# Nearest to road: rhus, cup, guyanese, elegance, quack, continuous, relay, outer,
# Nearest to existence: indignant, lambar, angelos, finegold, governance, depletion, presence, targaryen,
# Nearest to police: underground, systems, military, davenport, labor, philosophers, secretary, mussorgsky,
# Nearest to pressure: weep, rockford, clams, norepinephrine, cheques, schools, cubans, ranging,
# Average loss at step 92000: 2.691462
# Average loss at step 94000: 2.726722
# Average loss at step 96000: 2.708410
# Average loss at step 98000: 2.391407
# Average loss at step 100000: 2.421457
# Nearest to while: although, when, though, but, however, before, flapping, after,
# Nearest to one: saeima, two, madhu, widened, theologically, kwa, dsm, enumerative,
# Nearest to but: however, although, though, and, while, see, despite, which,
# Nearest to will: would, can, could, should, must, might, may, cannot,
# Nearest to many: some, several, numerous, various, those, most, all, few,
# Nearest to and: or, but, isopropanol, bipm, uncountably, including, though, capacities,
# Nearest to use: sense, neoclassicism, content, living, scope, revolving, throw, subtractive,
# Nearest to on: upon, through, around, in, incline, letting, at, seekers,
# Nearest to operating: numeral, nervous, defendants, storage, solar, file, nave, seq,
# Nearest to account: sexist, somaliland, happiness, summary, gath, nephritis, policeman, ordering,
# Nearest to active: important, operates, contained, utah, leveraged, posse, ural, earlier,
# Nearest to assembly: joram, serif, intimidated, lowers, ramayana, congress, zoological, skin,
# Nearest to road: rhus, cup, guyanese, quack, elegance, outer, relay, continuous,
# Nearest to existence: indignant, presence, angelos, depletion, lambar, finegold, origins, governance,
# Nearest to police: underground, military, davenport, systems, labor, decatur, campaign, philosophers,
# Nearest to pressure: weep, rockford, cubans, norepinephrine, cheques, clams, ranging, conflicts,
